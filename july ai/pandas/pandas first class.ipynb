# %%
Pandas --->
     is the extension of numpy

Numpy --> 2005
pandas ---> 2007

# %%
Pnadas:
    1) Data Cleaning
    2) Data Analysis
    3) Data Manupualtion
    4) Data Exploring

# %%
Pandas hold  -> 2 Data Structure:
    1) Series
    2) DataFrame

# %%
# !pip install pandas
# Out:
# ...
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
usernames = ["kriss", "moris", "ok", "hello", "surash", "pavan"]

# %%
type(usernames)
# Out:
# list

# %%
Series : --->
    a single column in a table is called series

# %%
usernames = ["kriss", "moris", "ok", "hello", "surash", "pavan"]

# %%
uname = pd.Series(usernames)

# %%
uname
# Out:
# 0     kriss
# 1     moris
# 2        ok
# 3     hello
# 4    surash
# 5     pavan
# dtype: object

# %%
type(uname)
# Out:
# pandas.core.series.Series

# %%
uname
# Out:
# 0     kriss
# 1     moris
# 2        ok
# 3     hello
# 4    surash
# 5     pavan
# dtype: object

# %%
uname[5]
# Out:
# 'pavan'

# %%
uname = pd.Series(usernames, index = ['a', 'b', 'c', 'd', 'e', 'f'])

# %%
uname
# Out:
# a     kriss
# b     moris
# c        ok
# d     hello
# e    surash
# f     pavan
# dtype: object

# %%
uname['d']
# Out:
# 'hello'

# %%
# DataFrame ---> its an complete table (rows or coloumns)

# %%
data = pd.DataFrame({
    "Username" : ["kriss", "moris", "ok", "hello", "surash", "pavan"],
    "Age" : [12, 23, 12, 32, 23, 23],
    "Phone_number" : [982634834, 982638463, 9826384634, 8273497364, 8234723684, 823478234]
})

# %%
data
# Out:
#   Username  Age  Phone_number
# 0    kriss   12     982634834
# 1    moris   23     982638463
# 2       ok   12    9826384634
# 3    hello   32    8273497364
# 4   surash   23    8234723684
# 5    pavan   23     823478234

# %%
datafrname[columnnamw]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
x = data["Phone_number"]

# %%
x
# Out:
# 0     982634834
# 1     982638463
# 2    9826384634
# 3    8273497364
# 4    8234723684
# 5     823478234
# Name: Phone_number, dtype: int64

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
# data[0]

# %%
data
# Out:
#   Username  Age  Phone_number
# 0    kriss   12     982634834
# 1    moris   23     982638463
# 2       ok   12    9826384634
# 3    hello   32    8273497364
# 4   surash   23    8234723684
# 5    pavan   23     823478234

# %%
# loc ----> help to get a single row data

# %%
data.iloc[0]
# Out:
# Username            kriss
# Age                    12
# Phone_number    982634834
# Name: 0, dtype: object

# %%
data = pd.DataFrame({
    "Username" : ["kriss", "moris", "ok", "hello", "surash", "pavan"],
    "Age" : [12, 23, 12, 32, 23, 23],
    "Phone_number" : [982634834, 982638463, 9826384634, 8273497364, 8234723684, 823478234]
}, index = ['a', 'b', 'c', 'd', 'e', 'f'])

# %%
data
# Out:
#   Username  Age  Phone_number
# a    kriss   12     982634834
# b    moris   23     982638463
# c       ok   12    9826384634
# d    hello   32    8273497364
# e   surash   23    8234723684
# f    pavan   23     823478234

# %%
data.loc["c"]
# Out:
# Username                ok
# Age                     12
# Phone_number    9826384634
# Name: c, dtype: object

# %%
# Series
# DataFrame
# loc

# %%
# Loading DataSet in Pandas

# %%
# Pandas Support : 
#     CSV
#     Excel
#     Json
#     HTMl
# .
# .
# .

# %%
df = pd.read_csv("Book_ipl22_ver_33.csv")

# %%
df
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
# Data Analysisis
# Data Exploring

# %%
head()
    --->return top 5 rows

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
df.head(12)
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# 5          6  March 30,2022            Dr DY Patil Sports Academy, Mumbai
# 6          7  March 31,2022                     Brabourne Stadium, Mumbai
# 7          8   April 1,2022                      Wankhede Stadium, Mumbai
# 8          9   April 2,2022            Dr DY Patil Sports Academy, Mumbai
# 9         10   April 2,2022  Maharashtra Cricket Association Stadium,Pune
# 10        11   April 3,2022                     Brabourne Stadium, Mumbai
# 11        12   April 4,2022            Dr DY Patil Sports Academy, Mumbai
#
# ...

# %%
# tail() --> retuhr last 5 rows

# %%
df.tail()
# Out:
#     match_id         date                             venue      team1  \
# 69        70  May 22,2022          Wankhede Stadium, Mumbai  Hyderabad
# 70        71  May 24,2022             Eden Gardens, Kolkata    Gujarat
# 71        72  May 25,2022             Eden Gardens, Kolkata   Banglore
# 72        73  May 27,2022  Narendra Modi Stadium, Ahmedabad   Banglore
# 73        74  May 29,2022  Narendra Modi Stadium, Ahmedabad    Gujarat
#
#         team2    stage toss_winner toss_decision  first_ings_score  \
# 69     Punjab    Group   Hyderabad           Bat               157
# 70  Rajasthan  Playoff     Gujarat         Field               188
# 71    Lucknow  Playoff     Lucknow         Field               207
# 72  Rajasthan  Playoff   Rajasthan         Field               157
# 73  Rajasthan    Final   Rajasthan           Bat               130
#
#     first_ings_wkts  second_ings_score  second_ings_wkts match_winner  \
# ...

# %%
df.tail(10)
# Out:
#     match_id         date                               venue      team1  \
# 64        65  May 17,2022            Wankhede Stadium, Mumbai  Hyderabad
# 65        66  May 18,2022  Dr DY Patil Sports Academy, Mumbai    Kolkata
# 66        67  May 19,2022            Wankhede Stadium, Mumbai   Banglore
# 67        68  May 20,2022           Brabourne Stadium, Mumbai    Chennai
# 68        69  May 21,2022            Wankhede Stadium, Mumbai      Delhi
# 69        70  May 22,2022            Wankhede Stadium, Mumbai  Hyderabad
# 70        71  May 24,2022               Eden Gardens, Kolkata    Gujarat
# 71        72  May 25,2022               Eden Gardens, Kolkata   Banglore
# 72        73  May 27,2022    Narendra Modi Stadium, Ahmedabad   Banglore
# 73        74  May 29,2022    Narendra Modi Stadium, Ahmedabad    Gujarat
#
#         team2    stage toss_winner toss_decision  first_ings_score  \
# 64     Mumbai    Group      Mumbai         Field               193
# ...

# %%
sample()
    return a single randmom row

# %%
df.sample()
# Out:
#     match_id         date                     venue  team1   team2  stage  \
# 68        69  May 21,2022  Wankhede Stadium, Mumbai  Delhi  Mumbai  Group
#
#    toss_winner toss_decision  first_ings_score  first_ings_wkts  \
# 68      Mumbai         Field               159                7
#
#     second_ings_score  second_ings_wkts match_winner   won_by  margin  \
# 68                160                 5       Mumbai  Wickets       5
#
#    player_of_the_match    top_scorer  highscore    best_bowling  \
# 68      Jasprit Bumrah  Ishan Kishan         48  Jasprit Bumrah
#
#    best_bowling_figure
# 68               3--25

# %%
df.sample(3)
# Out:
#     match_id           date                      venue      team1      team2  \
# 19        20  April 10,2022   Wankhede Stadium, Mumbai    Lucknow  Rajasthan
# 68        69    May 21,2022   Wankhede Stadium, Mumbai      Delhi     Mumbai
# 24        25  April 15,2022  Brabourne Stadium, Mumbai  Hyderabad    Kolkata
#
#     stage toss_winner toss_decision  first_ings_score  first_ings_wkts  \
# 19  Group     Lucknow         Field               165                6
# 68  Group      Mumbai         Field               159                7
# 24  Group   Hyderabad         Field               175                8
#
#     second_ings_score  second_ings_wkts match_winner   won_by  margin  \
# 19                162                 8    Rajasthan     Runs       3
# 68                160                 5       Mumbai  Wickets       5
# 24                176                 3    Hyderabad  Wickets       7
#
#    player_of_the_match       top_scorer  highscore      best_bowling  \
# ...

# %%
head()
tail()
sample()

# %%
# shape ---> number of rows and colunm=mns

# %%
df.shape
# Out:
# (74, 20)

# %%
# info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
# discribe() --> mixium infomation about only numarical clumns

# %%
df.describe()
# Out:
#         match_id  first_ings_score  first_ings_wkts  second_ings_score  \
# count  74.000000         74.000000        74.000000          74.000000
# mean   37.500000        171.121622         6.135135         158.540541
# std    21.505813         29.048355         2.222699          29.299207
# min     1.000000         68.000000         0.000000          72.000000
# 25%    19.250000        154.250000         5.000000         142.750000
# 50%    37.500000        169.500000         6.000000         160.000000
# 75%    55.750000        192.750000         8.000000         176.000000
# max    74.000000        222.000000        10.000000         211.000000
#
#        second_ings_wkts     margin   highscore
# count         74.000000  74.000000   74.000000
# mean           6.175676  16.972973   71.716216
# std            2.639832  19.651047   20.705052
# min            1.000000   2.000000   28.000000
# 25%            4.000000   5.250000   57.000000
# ...

# %%
# df

# %%
# loc --->

# %%
# iloc[]

# %%
# dataframw.iloc[rows, columns]

# %%
df
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
df.iloc[[2, 3], [3, 4, 5, 6, 7]]
# Out:
#       team1    team2  stage toss_winner toss_decision
# 2  Banglore   Punjab  Group      Punjab         Field
# 3   Gujarat  Lucknow  Group     Gujarat         Field

# %%
df.iloc[[2, 3], 3 : 8]
# Out:
#       team1    team2  stage toss_winner toss_decision
# 2  Banglore   Punjab  Group      Punjab         Field
# 3   Gujarat  Lucknow  Group     Gujarat         Field

# %%
df.iloc[10 : 15, 3 : 8]
# Out:
#         team1      team2  stage toss_winner toss_decision
# 10    Chennai     Punjab  Group     Chennai         Field
# 11  Hyderabad    Lucknow  Group   Hyderabad         Field
# 12   Banglore  Rajasthan  Group    Banglore         Field
# 13    Kolkata     Mumbai  Group     Kolkata         Field
# 14      Delhi    Lucknow  Group     Lucknow         Field
