# %%
import numpy as np

# %%
# genrate dataset

x = 6 * np.random.rand(200, 1) - 3
y = 0.8 * x**2 + 0.9 * x + 2 + np.random.randn(200, 1)

# %%
x
# Out:
# array([[-0.94127894],
#        [-0.9001512 ],
#        [ 0.49428178],
#        [-2.33134502],
#        [ 0.98611195],
#        [-0.96769165],
#        [ 2.6222457 ],
#        [-2.93363056],
#        [-0.33172641],
#        [ 2.94362081],
#        [ 1.22354552],
#        [-1.66714857],
#        [ 1.49837935],
#        [ 2.94744507],
#        [-0.98952434],
#        [ 0.43417613],
#        [-1.64860909],
#        [ 2.46213197],
#        [ 2.04392384],
#        [ 2.46411756],
#        [ 1.91904511],
#        [-1.55646974],
#        [ 2.25613848],
#        [-0.63218284],
#        [ 0.98699527],
#        [-0.24499222],
#        [ 1.41543838],
#        [-0.00457631],
#        [ 0.40738333],
#        [-1.97693335],
#        [ 1.02348479],
#        [ 1.37545068],
#        [-1.52113007],
#        [-1.98809615],
#        [-0.75925244],
#        [-2.21923616],
#        [ 0.49786778],
#        [ 1.21307602],
#        [ 1.1463983 ],
#        [-2.10183651],
#        [ 0.45638962],
# ...

# %%
y
# Out:
# array([[ 2.0027305 ],
#        [ 1.49586083],
#        [ 3.58633741],
#        [ 2.83487309],
#        [ 3.30692513],
#        [ 1.2805241 ],
#        [ 9.18747771],
#        [ 5.76502208],
#        [ 1.14107839],
#        [11.83468205],
#        [ 3.2648965 ],
#        [ 2.66324725],
#        [ 6.06026033],
#        [11.04813525],
#        [ 2.00855501],
#        [ 3.75401828],
#        [ 3.03201477],
#        [ 8.72949058],
#        [ 9.73423373],
#        [ 7.97801344],
#        [ 7.26135154],
#        [-0.72832797],
#        [ 6.75094055],
#        [ 2.96108231],
#        [ 3.81913638],
#        [ 1.87460529],
#        [ 7.14897082],
#        [ 1.06310067],
#        [ 0.31884818],
#        [ 4.01187955],
#        [ 3.24715809],
#        [ 6.10113172],
#        [ 2.26712572],
#        [ 3.44754956],
#        [ 3.24219039],
#        [ 2.7706253 ],
#        [ 2.68008873],
#        [ 4.91374632],
#        [ 1.43934082],
#        [ 5.59571742],
#        [ 4.07300654],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
x.shape
# Out:
# (200, 1)

# %%
x_train.shape
# Out:
# (160, 1)

# %%
x_test.shape
# Out:
# (40, 1)

# %%
plt.scatter(x_train, y_train, color = "red", label = "Traning Data")
plt.scatter(x_test, y_test, color = "green", label = "Testing Data")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.legend()

# %%
# simple linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train, y_train, color = "red", label = "Traning Data")
plt.scatter(x_test, y_test, color = "green", label = "Testing Data")
plt.plot(x_test, linear_model.predict(x_test), color = "blue", label = "predicted line")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.legend()

# %%
y_pred = linear_model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.20380969565418183

# %% [markdown]
# # Polynomial Linear regression

# %%
plt.scatter(x_train, y_train, color = "red", label = "Traning Data")
plt.scatter(x_test, y_test, color = "green", label = "Testing Data")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.legend()

# %%
# ploynomial feature

# %%
x
# Out:
# array([[-0.94127894],
#        [-0.9001512 ],
#        [ 0.49428178],
#        [-2.33134502],
#        [ 0.98611195],
#        [-0.96769165],
#        [ 2.6222457 ],
#        [-2.93363056],
#        [-0.33172641],
#        [ 2.94362081],
#        [ 1.22354552],
#        [-1.66714857],
#        [ 1.49837935],
#        [ 2.94744507],
#        [-0.98952434],
#        [ 0.43417613],
#        [-1.64860909],
#        [ 2.46213197],
#        [ 2.04392384],
#        [ 2.46411756],
#        [ 1.91904511],
#        [-1.55646974],
#        [ 2.25613848],
#        [-0.63218284],
#        [ 0.98699527],
#        [-0.24499222],
#        [ 1.41543838],
#        [-0.00457631],
#        [ 0.40738333],
#        [-1.97693335],
#        [ 1.02348479],
#        [ 1.37545068],
#        [-1.52113007],
#        [-1.98809615],
#        [-0.75925244],
#        [-2.21923616],
#        [ 0.49786778],
#        [ 1.21307602],
#        [ 1.1463983 ],
#        [-2.10183651],
#        [ 0.45638962],
# ...

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree = 10)

# %%
x_train_new = poly.fit_transform(x_train)

# %%
x_test_new = poly.fit_transform(x_test)

# %%
x_test
# Out:
# array([[-0.75925244],
#        [ 0.98699527],
#        [ 2.50511579],
#        [-1.14644796],
#        [ 0.08502966],
#        [-1.01349539],
#        [-2.32879687],
#        [-2.92687191],
#        [ 1.76598256],
#        [ 1.0666033 ],
#        [-1.12307056],
#        [-0.06545473],
#        [ 1.73982194],
#        [-2.85706222],
#        [-2.41829597],
#        [-2.75418316],
#        [-0.75902113],
#        [ 2.94744507],
#        [ 2.5683793 ],
#        [-1.73988636],
#        [ 0.40738333],
#        [-0.18549559],
#        [-0.44915129],
#        [ 0.01799399],
#        [-2.50096067],
#        [ 0.97289192],
#        [ 0.98611195],
#        [-0.44605363],
#        [ 2.13798323],
#        [ 1.72502886],
#        [ 2.25613848],
#        [ 2.10815248],
#        [-0.3059441 ],
#        [ 0.49428178],
#        [ 2.04392384],
#        [-2.15872036],
#        [ 1.41483034],
#        [ 0.4201418 ],
#        [-0.2733369 ],
#        [ 0.99843162]])

# %%
x_test_new
# Out:
# array([[ 1.00000000e+00, -7.59252438e-01,  5.76464265e-01,
#         -4.37681899e-01,  3.32311049e-01, -2.52307974e-01,
#          1.91565445e-01, -1.45446531e-01,  1.10430633e-01,
#         -8.38447277e-02,  6.36593140e-02],
#        [ 1.00000000e+00,  9.86995273e-01,  9.74159669e-01,
#          9.61490989e-01,  9.48987062e-01,  9.36645744e-01,
#          9.24464922e-01,  9.12442508e-01,  9.00576443e-01,
#          8.88864692e-01,  8.77305250e-01],
#        [ 1.00000000e+00,  2.50511579e+00,  6.27560510e+00,
#          1.57211174e+01,  3.93832193e+01,  9.86595244e+01,
#          2.47153532e+02,  6.19148214e+02,  1.55103797e+03,
#          3.88552969e+03,  9.73370176e+03],
#        [ 1.00000000e+00, -1.14644796e+00,  1.31434293e+00,
#         -1.50682577e+00,  1.72749733e+00, -1.98048579e+00,
#          2.27052389e+00, -2.60303748e+00,  2.98424701e+00,
#         -3.42128390e+00,  3.92232395e+00],
#        [ 1.00000000e+00,  8.50296579e-02,  7.23004273e-03,
# ...

# %%
ploy_model = LinearRegression()

# %%
ploy_model.fit(x_train_new, y_train)
# Out:
# LinearRegression()

# %%
y_pred_poly = ploy_model.predict(x_test_new)

# %%
r2_score(y_pred_poly, y_test)
# Out:
# 0.847415438884757

# %%
plt.scatter(x_train, y_train, color = "red", label = "Traning Data")
plt.scatter(x_test, y_test, color = "green", label = "Testing Data")
plt.plot(x_test, y_pred_poly, color = "blue", label = "Predicted Line")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.legend()

# %%
x_new = np.linspace(-3, 3, 200).reshape(200, 1)
x_new_ploy = poly.fit_transform(x_new)
y_new = ploy_model.predict(x_new_ploy)

# %%
plt.scatter(x_train, y_train, color = "red", label = "Traning Data")
plt.scatter(x_test, y_test, color = "green", label = "Testing Data")
plt.plot(x_new, y_new, color = "blue", label = "Predicted Line", linewidth = 3)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.legend()
