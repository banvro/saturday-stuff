# %%
# !pip install pandas

# %%
numpy : 2005

pandas : 2008

# %%
TYpe of data structur:
    1) Series
    2) DataFrame
# Out:
#   Cell In[81], line 2
#     1) Series
#      ^
# SyntaxError: unmatched ')'

# %%
import pandas as pd
import numpy as np

# %%
zx = np.array([23, 45, 67, 89, 56, 4, 78, 45])

# %%
zx

# %%
sr = pd.Series(zx)

# %%
sr

# %%
type(sr)

# %%
sr = pd.Series(zx, index = ["a", "b", "c", "d", "e", "f", "g", "h"])

# %%
sr

# %%
data = pd.DataFrame({
    "Name" : ["kriss", "moris", "hey", "hello", "ok", "done", "Maehs"],
    "Age" : [20, 34, 45, 23, 45, 34, 23],
    "Phone Number" : [9283648328, 983648924, 923432643, 8723487345, 86239486343, 823493423, 9283694343]
})

# %%
data

# %%
type(data)

# %%
data = pd.read_csv("IPL Matches 2008-2020.csv")

# %%
data

# %%
# head() ----> its return top 5 rows

# %%
data.head(10)

# %%
data.tail(3)

# %%
data.sample(3)
# Out:
#           id    city        date player_of_match  \
# 719  1178399  Mumbai  2019-04-10      KA Pollard
# 679  1136604  Indore  2018-05-12       SP Narine
# 794  1216530   Dubai  2020-11-01      PJ Cummins
#
#                                    venue  neutral_venue  \
# 719                     Wankhede Stadium              0
# 679               Holkar Cricket Stadium              0
# 794  Dubai International Cricket Stadium              0
#
#                      team1                  team2       toss_winner  \
# 719         Mumbai Indians        Kings XI Punjab    Mumbai Indians
# 679        Kings XI Punjab  Kolkata Knight Riders   Kings XI Punjab
# 794  Kolkata Knight Riders       Rajasthan Royals  Rajasthan Royals
#
#     toss_decision                 winner   result  result_margin eliminator  \
# 719         field         Mumbai Indians  wickets            3.0          N
# 679         field  Kolkata Knight Riders     runs           31.0          N
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
data.shape
# Out:
# (816, 17)

# %%
data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
type(data["toss_decision"])
# Out:
# pandas.core.series.Series

# %%
data["toss_decision"]
# Out:
# 0      field
# 1        bat
# 2        bat
# 3        bat
# 4        bat
#        ...
# 811    field
# 812    field
# 813    field
# 814      bat
# 815      bat
# Name: toss_decision, Length: 816, dtype: object

# %%
# loc[]

# %%
data.loc[1]
# Out:
# id                                                     335983
# city                                               Chandigarh
# date                                               2008-04-19
# player_of_match                                    MEK Hussey
# venue              Punjab Cricket Association Stadium, Mohali
# neutral_venue                                               0
# team1                                         Kings XI Punjab
# team2                                     Chennai Super Kings
# toss_winner                               Chennai Super Kings
# toss_decision                                             bat
# winner                                    Chennai Super Kings
# result                                                   runs
# result_margin                                            33.0
# eliminator                                                  N
# method                                                    NaN
# ...

# %%
data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
data.loc[[1, 6, 8, 9]]
# Out:
#        id        city        date player_of_match  \
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 6  335988   Hyderabad  2008-04-22        V Sehwag
# 8  335990   Hyderabad  2008-04-24       YK Pathan
# 9  335991  Chandigarh  2008-04-25   KC Sangakkara
#
#                                         venue  neutral_venue            team1  \
# 1  Punjab Cricket Association Stadium, Mohali              0  Kings XI Punjab
# 6   Rajiv Gandhi International Stadium, Uppal              0  Deccan Chargers
# 8   Rajiv Gandhi International Stadium, Uppal              0  Deccan Chargers
# 9  Punjab Cricket Association Stadium, Mohali              0  Kings XI Punjab
#
#                  team2          toss_winner toss_decision  \
# 1  Chennai Super Kings  Chennai Super Kings           bat
# 6     Delhi Daredevils      Deccan Chargers           bat
# 8     Rajasthan Royals     Rajasthan Royals         field
# 9       Mumbai Indians       Mumbai Indians         field
#
# ...

# %%
data.head(3)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
#
#                          team1                  team2  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders
# 1              Kings XI Punjab    Chennai Super Kings
# 2             Delhi Daredevils       Rajasthan Royals
#
#                    toss_winner toss_decision                 winner   result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders     runs
# 1          Chennai Super Kings           bat    Chennai Super Kings     runs
# ...

# %%
data["team1"]
# Out:
# 0      Royal Challengers Bangalore
# 1                  Kings XI Punjab
# 2                 Delhi Daredevils
# 3                   Mumbai Indians
# 4            Kolkata Knight Riders
#                   ...
# 811    Royal Challengers Bangalore
# 812                 Mumbai Indians
# 813    Royal Challengers Bangalore
# 814                 Delhi Capitals
# 815                 Delhi Capitals
# Name: team1, Length: 816, dtype: object

# %%
data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
# iloc[]

# %%
# data.iloc[rows, columns]

# %%
data.iloc[0:3 , [6, 7, 9]]
# Out:
#                          team1                  team2 toss_decision
# 0  Royal Challengers Bangalore  Kolkata Knight Riders         field
# 1              Kings XI Punjab    Chennai Super Kings           bat
# 2             Delhi Daredevils       Rajasthan Royals           bat

# %%
# Data Cleaning::::::

# %%
newdata = pd.read_csv("heart.csv")

# %%
newdata
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           NaN        140          289          0  NormalATA
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
xdata = pd.read_csv("zim_test.csv")

# %%
xdata
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
xdata
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
xdata.shape
# Out:
# (169, 4)

# %%
xdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
xdata[xdata.isnull().any(axis = 1)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 17         45     90       112       NaN
# 27         60    103       132       NaN
# 91         45    107       137       NaN
# 118        60    105       125       NaN
# 141        60     97       127       NaN

# %%
1) remove rows which hold empty cells
2) add something in empty cells

# %%
# 1) remove rows which hold empty cells

# dropna()

# %%
xdata.shape
# Out:
# (169, 4)

# %%
xdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
# inplace = True

# %%
xdata.dropna(inplace = True)

# %%
xdata.shape
# Out:
# (164, 4)

# %%
xdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 164 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  164 non-null    int64
#  1   Pulse     164 non-null    int64
#  2   Maxpulse  164 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.4 KB

# %%
ydata = pd.read_csv("zim_test.csv")

# %%
ydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
ydata[ydata.isnull().any(axis = True)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 17         45     90       112       NaN
# 27         60    103       132       NaN
# 91         45    107       137       NaN
# 118        60    105       125       NaN
# 141        60     97       127       NaN

# %%
ydata.head(20)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112       NaN
# 18        60    103       123     323.0
# 19        45     97       125     243.0

# %%
# fillna()

# %%
ydata.fillna(120, inplace = True)

# %%
ydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  169 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
ydata.head(20)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112     120.0
# 18        60    103       123     323.0
# 19        45     97       125     243.0

# %%
ydata["Duration"].fillna(60, inplace=True)

# %%
zx = ydata["Duration"].median()

# %%
ydata["Duration"].fillna(zx, inplace=True)

# %%
# data["result_margin"].fillna(1200, inplace=True)

# %%
# tdata["balls"]

# %%
x = pd.read_csv("zim_test.csv")

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
yu = x["Calories"].mean()

# %%
x["Calories"].fillna(yu, inplace = True)

# %%
yu
# Out:
# 375.79024390243904

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  169 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
x.head(20)
# Out:
#     Duration  Pulse  Maxpulse    Calories
# 0         60    110       130  409.100000
# 1         60    117       145  479.000000
# 2         60    103       135  340.000000
# 3         45    109       175  282.400000
# 4         45    117       148  406.000000
# 5         60    102       127  300.000000
# 6         60    110       136  374.000000
# 7         45    104       134  253.300000
# 8         30    109       133  195.100000
# 9         60     98       124  269.000000
# 10        60    103       147  329.300000
# 11        60    100       120  250.700000
# 12        60    106       128  345.300000
# 13        60    104       132  379.300000
# 14        60     98       123  275.000000
# 15        60     98       120  215.200000
# 16        60    100       120  300.000000
# 17        45     90       112  375.790244
# 18        60    103       123  323.000000
# 19        45     97       125  243.000000

# %%
# x.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# Length: 169, dtype: bool

# %%
x.drop_duplicates()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [162 rows x 4 columns]
